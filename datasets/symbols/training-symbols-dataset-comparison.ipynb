# %%
# =============================================================================
# Created By:     Kai Metzger
# Created School: Franz-Oberthuer-Schule Wuerzburg
# Created Email:  metzgerkai@franz-oberthuer-schule.de
# Created Date:   Fri December 06 18:08 UTC 2024
# Version:        1.0
# =============================================================================
"""The Module has been build for training the symbols dataset with images + 
ground truth on a Raspberry Pi 5 with a standard USB camera. An image with a 
resolution of 640px x 480px can be recorded with the Python script 
create-symbols-dataset.py.
The files in the dataset <2023 symbols> should be ordered in the following
manner:             > explanation
- 2023 symbols      
  - dataset3        > dataset version (dataset1 - 3 where used in the project)
    - data          > images (.png files)
    - gt            > ground truth (.txt files with class labels 1-4)
"""

# =============================================================================
# Import
# =============================================================================
import cv2
import os
import numpy as np
from tensorflow.keras import layers, models, utils, callbacks
import matplotlib.pyplot as plt

# Enable Nvidia GPUs by un-commenting this line 
#os.environ["CUDA_VISIBLE_DEVICES"] = "-1"
#XLA_FLAGS="--xla_gpu_cuda_data_dir=/usr/"

# To get reproducable results with the same training setting random seed
SEED = 42
np.random.seed(SEED)

# Flags
plots_on = True
test_on_specific_image = False

# %%
# =============================================================================
# Define functions
# =============================================================================
# Change image size and convert to grayscale images
def pic_prep (image, x, y):
  image = cv2.resize(image, (y,x)) # change image size
  image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY) # convert to grayscale
  image = image / 255 # image normalization
  return image

# Shuffle images
def unison_shuffle(a, b):
    assert len(a) == len(b)
    p = np.random.permutation(len(a))
    return a[p], b[p]

# todo: only show output of training for every 10 epochs
# Add callback to only print loss etc. after e.g. 10 epochs:
# https://stackoverflow.com/questions/44931689/how-to-disable-printing-reports-after-each-epoch-in-keras
class callback_print(callbacks.Callback):
    SHOW_NUMBER = 10
    counter = 0
    epoch = 0

    def on_epoch_begin(self, epoch, logs=None):
        self.epoch = epoch

    def on_train_batch_end(self, batch, logs=None):
        if self.counter == self.SHOW_NUMBER or self.epoch == 1:
            print('Epoch: ' + str(self.epoch) + ' loss: ' + str(logs['loss']))
            if self.epoch > 1:
                self.counter = 0
        self.counter += 1

# %%
# =============================================================================
# Function with some hypterparameters to change for comparison
# =============================================================================
def train_symbols_model(num_training=0,
                        image_size=[32, 28], #
                        num_neurons_per_layer=[64,32,16,4],
                        batch_size=4,
                        epochs=300):
    # =============================================================================
    # Declare variables
    # =============================================================================
    img_size_x = image_size[0]
    img_size_y = image_size[1]
    img_dim = img_size_x * img_size_y

    # Change the following paths to your dataset path
    home_dir = os.path.expanduser("~")
    img_dir = home_dir + "/ml_project/datasets/symbols/dataset1/data"
    gt_dir = home_dir + "/ml_project/datasets/symbols/dataset1/gt"
    checkpoint_filepath = home_dir + "/ml_project/datasets/symbols/dataset1/chpt/"

    # =============================================================================
    # Get number of data (image/label) 
    # =============================================================================
    anz_data = len(os.listdir(img_dir))
    anz_data = int(anz_data) - 1
    dataset = np.zeros((anz_data, img_size_x, img_size_y), dtype=float)
    ground_truth = np.zeros((anz_data), dtype=int)
    #print("dataset size:", anz_data)

    # =============================================================================
    # Callback for training
    # =============================================================================
    model_checkpoint_callback = callbacks.ModelCheckpoint(
        filepath=checkpoint_filepath + str(num_training) + "-chpt.model.keras",
        save_weights_only=False,
        monitor='val_accuracy',
        mode='auto',
        save_best_only=True,
        verbose = 1)
    
    # =============================================================================
    # Read dataset
    # =============================================================================
    for i in range(0, anz_data, 1):
        img_name = img_dir + '/' + str(i) + '.png'      # create file names
        image = cv2.imread(img_name)                    # read image
        image = pic_prep(image, img_size_x, img_size_y) # prepare image
        dataset[i,:,:] = image                          # 2d-image to 3d-array
        
        txt_name = gt_dir + '/' + str(i) + '.txt'       # create gt file names
        ground_truth[i] = np.genfromtxt(txt_name, delimiter=',') 

    # =============================================================================
    # Prepare dataset: train set (80%) and test set (20%)
    # =============================================================================
    dataset = dataset.reshape(anz_data, img_dim) # convert into 2d array (all pixel in one row)
    ground_truth = ground_truth.reshape(anz_data, 1)

    dataset, ground_truth = unison_shuffle(dataset, ground_truth)

    trainset = np.random.choice(dataset.shape[0],
                                int(dataset.shape[0]*0.80), 
                                replace=False)
    train_data = dataset[trainset,:]
    train_gt = ground_truth[trainset]
    train_gt = utils.to_categorical(train_gt, 4)

    testset = np.delete(np.arange(0, len(ground_truth) ), 
                        trainset) 
    test_data = dataset[testset,:]
    test_gt = ground_truth[testset]
    test_gt = utils.to_categorical(test_gt, 4)
    #print(ground_truth)
    #print(dataset)
    #print(trainset)
    #print(train_data)
    #print(train_gt)

    # =============================================================================
    # Create neural network with e.g. 4 layers and (64, 32, 16, 4) neurons per layer.
    # =============================================================================
    model = models.Sequential()
    model.add(layers.Dense(num_neurons_per_layer[0], input_dim=img_dim,activation='relu'))
    model.add(layers.Dense(num_neurons_per_layer[1], activation='relu'))
    model.add(layers.Dense(num_neurons_per_layer[2], activation='relu'))
    model.add(layers.Dense(num_neurons_per_layer[3], activation='sigmoid'))
    model.compile(loss='mean_squared_error', 
                  optimizer='adam', 
                  metrics=['accuracy'])

    # =============================================================================
    # Train the neuronal network e.g. for e.g. 300 epochs.
    # =============================================================================
    history = model.fit(train_data, 
                        train_gt, 
                        batch_size=batch_size, 
                        epochs=epochs, 
                        verbose=0, 
                        shuffle=True, 
                        validation_data=(test_data, test_gt), 
                        callbacks=[model_checkpoint_callback])
    
    # =============================================================================
    # Plot train and val accuracy.
    # =============================================================================
    if plots_on:
        plt.plot(history.history['accuracy'], label='accuracy')
        plt.plot(history.history['val_accuracy'], label='val_accuracy')
        plt.xlabel('Epoch')
        plt.ylabel('Accuracy')
        plt.legend(loc='lower right')
        plt.show()

        # =========================================================================
        # Plot train and val loss.
        # =========================================================================
        plt.plot(history.history['loss'], label='loss')
        plt.plot(history.history['val_loss'], label='val_loss')
        plt.xlabel('Epoch')
        plt.ylabel('Loss')
        plt.legend(loc='lower left')
        plt.show()
    
    if test_on_specific_image:
        # =========================================================================
        # Load pretrained dataset weights to e.g. test on new (unseen) data.
        # =========================================================================
        model.load_weights(checkpoint_filepath + ".keras")   

        # =========================================================================
        # Test dataset on xxx.
        # =========================================================================
        score = model.evaluate(test_data, test_gt, verbose=1)
        print('Test score:', score[0])
        print('Test accuracy:', score[1])       

        # =========================================================================
        # Testing on a single image.
        # =========================================================================
        data_pred = np.zeros((1, img_size_x, img_size_y), dtype=float)
        img_pred = cv2.imread(home_dir + "/ml_project/datasets/symbols/dataset1/data/13.png")
        img_pred = pic_prep(img_pred, img_size_x, img_size_y)
        data_pred[0,:,:] = img_pred
        data_pred = data_pred.reshape(1,img_dim)
        result = model.predict(data_pred)
        result = np.round(result, decimals=2)
        print("Probability for class (cross, circle, triangle, square) in percent", 
            result)
        
        # =============================================================================
        # Output class: 
        # translate class label (0,1,2,3) to class (cross, circle, triangle, square).
        # =============================================================================
        max_res = 0
        res_index = 4
        for i in range(0, 4, 1):
            if result[0,i] > max_res:
                max_res = result[0,i]
                res_index = i

        if res_index == 0:
            print('Cross detected!')
        elif res_index == 1:
            print('Circle detected!')
        elif res_index == 2:
            print('Triangle detected!')
        elif res_index == 3:
            print('Square detected!')
        elif res_index == 4:
            print('Error!')

# %%
# =============================================================================
# Train multiple networks with differend image scales and neurons per layer
# =============================================================================
"""
image_dims = [[32, 28],
              [32, 28],
              [32, 28]]
neurons_layers = [[64,32,16,4],
                  [32,32,16,4],
                  [16,32,16,4]]
"""
image_dims = [[32, 28],
              [32, 28],
              [32, 28],
              [32, 28],
              [32, 28]]
neurons_layers = [[256,32,16,4],
                  [128,32,16,4],
                  [64,32,16,4],
                  [32,32,16,4],
                  [16,32,16,4]]

# Train multiple times with different hyper parameters (dim img size, neurons per layer)
i = 1
for img_size, num_neurons in zip(image_dims, neurons_layers):
    print("Training", i, "with image size", img_size, "and", num_neurons, "neurons per layer")
    train_symbols_model(i, img_size, num_neurons, 4, 300)
    print("#################################################\n")
    i+=1
# Out:
# Training 1 with image size [32, 28] and [256, 32, 16, 4] neurons per layer
# /home/metzgeka/tensorflow/lib/python3.12/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2025-01-11 11:39:50.908859: E external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:282] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2025-01-11 11:39:50.908879: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:134] retrieving CUDA diagnostic information for host: fos-deeplearning
# 2025-01-11 11:39:50.908882: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:141] hostname: fos-deeplearning
# 2025-01-11 11:39:50.908948: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:165] libcuda reported version is: 550.127.8
# 2025-01-11 11:39:50.908959: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:169] kernel reported version is: 550.127.8
# 2025-01-11 11:39:50.908961: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:248] kernel version seems to match DSO: 550.127.8
# Epoch 1: val_accuracy improved from -inf to 0.22857, saving model to /home/metzgeka/ml_project/datasets/symbols/dataset1/chpt/1-chpt.model.keras
#
# Epoch 2: val_accuracy did not improve from 0.22857
#
# Epoch 3: val_accuracy did not improve from 0.22857
#
# Epoch 4: val_accuracy did not improve from 0.22857
#
# Epoch 5: val_accuracy did not improve from 0.22857
#
# Epoch 6: val_accuracy improved from 0.22857 to 0.25714, saving model to /home/metzgeka/ml_project/datasets/symbols/dataset1/chpt/1-chpt.model.keras
#
# Epoch 7: val_accuracy did not improve from 0.25714
#
# Epoch 8: val_accuracy did not improve from 0.25714
#
# Epoch 9: val_accuracy did not improve from 0.25714
#
# Epoch 10: val_accuracy improved from 0.25714 to 0.31429, saving model to /home/metzgeka/ml_project/datasets/symbols/dataset1/chpt/1-chpt.model.keras
#
# Epoch 11: val_accuracy did not improve from 0.31429
#
# Epoch 12: val_accuracy did not improve from 0.31429
#
# Epoch 13: val_accuracy did not improve from 0.31429
#
# Epoch 14: val_accuracy did not improve from 0.31429
#
# Epoch 15: val_accuracy did not improve from 0.31429
#
# Epoch 16: val_accuracy did not improve from 0.31429
#
# Epoch 17: val_accuracy did not improve from 0.31429
#
# Epoch 18: val_accuracy did not improve from 0.31429
#
# Epoch 19: val_accuracy did not improve from 0.31429
#
# Epoch 20: val_accuracy did not improve from 0.31429
#
# Epoch 21: val_accuracy did not improve from 0.31429
#
# Epoch 22: val_accuracy did not improve from 0.31429
#
# Epoch 23: val_accuracy did not improve from 0.31429
#
# Epoch 24: val_accuracy did not improve from 0.31429
#
# Epoch 25: val_accuracy did not improve from 0.31429
#
# Epoch 26: val_accuracy did not improve from 0.31429
#
# Epoch 27: val_accuracy did not improve from 0.31429
#
# Epoch 28: val_accuracy did not improve from 0.31429
#
# Epoch 29: val_accuracy did not improve from 0.31429
#
# Epoch 30: val_accuracy did not improve from 0.31429
#
# Epoch 31: val_accuracy did not improve from 0.31429
#
# Epoch 32: val_accuracy did not improve from 0.31429
#
# Epoch 33: val_accuracy did not improve from 0.31429
#
# Epoch 34: val_accuracy did not improve from 0.31429
#
# Epoch 35: val_accuracy did not improve from 0.31429
#
# Epoch 36: val_accuracy did not improve from 0.31429
#
# Epoch 37: val_accuracy did not improve from 0.31429
#
# Epoch 38: val_accuracy did not improve from 0.31429
#
# Epoch 39: val_accuracy did not improve from 0.31429
#
# Epoch 40: val_accuracy did not improve from 0.31429
#
# Epoch 41: val_accuracy did not improve from 0.31429
#
# Epoch 42: val_accuracy did not improve from 0.31429
#
# Epoch 43: val_accuracy did not improve from 0.31429
#
# Epoch 44: val_accuracy did not improve from 0.31429
#
# Epoch 45: val_accuracy improved from 0.31429 to 0.37143, saving model to /home/metzgeka/ml_project/datasets/symbols/dataset1/chpt/1-chpt.model.keras
#
# Epoch 46: val_accuracy did not improve from 0.37143
#
# Epoch 47: val_accuracy did not improve from 0.37143
#
# Epoch 48: val_accuracy did not improve from 0.37143
#
# Epoch 49: val_accuracy did not improve from 0.37143
#
# Epoch 50: val_accuracy did not improve from 0.37143
#
# Epoch 51: val_accuracy did not improve from 0.37143
#
# Epoch 52: val_accuracy did not improve from 0.37143
#
# Epoch 53: val_accuracy did not improve from 0.37143
#
# Epoch 54: val_accuracy did not improve from 0.37143
#
# Epoch 55: val_accuracy did not improve from 0.37143
#
# Epoch 56: val_accuracy did not improve from 0.37143
#
# Epoch 57: val_accuracy did not improve from 0.37143
#
# Epoch 58: val_accuracy did not improve from 0.37143
#
# Epoch 59: val_accuracy did not improve from 0.37143
#
# Epoch 60: val_accuracy did not improve from 0.37143
#
# Epoch 61: val_accuracy did not improve from 0.37143
#
# Epoch 62: val_accuracy did not improve from 0.37143
#
# Epoch 63: val_accuracy did not improve from 0.37143
#
# Epoch 64: val_accuracy did not improve from 0.37143
#
# Epoch 65: val_accuracy did not improve from 0.37143
#
# Epoch 66: val_accuracy did not improve from 0.37143
#
# Epoch 67: val_accuracy improved from 0.37143 to 0.42857, saving model to /home/metzgeka/ml_project/datasets/symbols/dataset1/chpt/1-chpt.model.keras
#
# Epoch 68: val_accuracy did not improve from 0.42857
#
# Epoch 69: val_accuracy did not improve from 0.42857
#
# Epoch 70: val_accuracy did not improve from 0.42857
#
# Epoch 71: val_accuracy did not improve from 0.42857
#
# Epoch 72: val_accuracy did not improve from 0.42857
#
# Epoch 73: val_accuracy did not improve from 0.42857
#
# Epoch 74: val_accuracy did not improve from 0.42857
#
# Epoch 75: val_accuracy did not improve from 0.42857
#
# Epoch 76: val_accuracy did not improve from 0.42857
#
# Epoch 77: val_accuracy did not improve from 0.42857
#
# Epoch 78: val_accuracy did not improve from 0.42857
#
# Epoch 79: val_accuracy did not improve from 0.42857
#
# Epoch 80: val_accuracy did not improve from 0.42857
#
# Epoch 81: val_accuracy did not improve from 0.42857
#
# Epoch 82: val_accuracy did not improve from 0.42857
#
# Epoch 83: val_accuracy did not improve from 0.42857
#
# Epoch 84: val_accuracy did not improve from 0.42857
#
# Epoch 85: val_accuracy did not improve from 0.42857
#
# Epoch 86: val_accuracy did not improve from 0.42857
#
# Epoch 87: val_accuracy did not improve from 0.42857
#
# Epoch 88: val_accuracy did not improve from 0.42857
#
# Epoch 89: val_accuracy did not improve from 0.42857
#
# Epoch 90: val_accuracy did not improve from 0.42857
#
# Epoch 91: val_accuracy did not improve from 0.42857
#
# Epoch 92: val_accuracy did not improve from 0.42857
#
# Epoch 93: val_accuracy did not improve from 0.42857
#
# Epoch 94: val_accuracy did not improve from 0.42857
#
# Epoch 95: val_accuracy did not improve from 0.42857
#
# Epoch 96: val_accuracy did not improve from 0.42857
#
# Epoch 97: val_accuracy did not improve from 0.42857
#
# Epoch 98: val_accuracy did not improve from 0.42857
#
# Epoch 99: val_accuracy did not improve from 0.42857
#
# Epoch 100: val_accuracy did not improve from 0.42857
#
# Epoch 101: val_accuracy did not improve from 0.42857
#
# Epoch 102: val_accuracy did not improve from 0.42857
#
# Epoch 103: val_accuracy did not improve from 0.42857
#
# Epoch 104: val_accuracy did not improve from 0.42857
#
# Epoch 105: val_accuracy did not improve from 0.42857
#
# Epoch 106: val_accuracy improved from 0.42857 to 0.48571, saving model to /home/metzgeka/ml_project/datasets/symbols/dataset1/chpt/1-chpt.model.keras
#
# Epoch 107: val_accuracy did not improve from 0.48571
#
# Epoch 108: val_accuracy did not improve from 0.48571
#
# Epoch 109: val_accuracy did not improve from 0.48571
#
# Epoch 110: val_accuracy did not improve from 0.48571
#
# Epoch 111: val_accuracy did not improve from 0.48571
#
# Epoch 112: val_accuracy did not improve from 0.48571
#
# Epoch 113: val_accuracy did not improve from 0.48571
#
# Epoch 114: val_accuracy did not improve from 0.48571
#
# Epoch 115: val_accuracy did not improve from 0.48571
#
# Epoch 116: val_accuracy did not improve from 0.48571
#
# Epoch 117: val_accuracy did not improve from 0.48571
#
# Epoch 118: val_accuracy did not improve from 0.48571
#
# Epoch 119: val_accuracy did not improve from 0.48571
#
# Epoch 120: val_accuracy did not improve from 0.48571
#
# Epoch 121: val_accuracy did not improve from 0.48571
#
# Epoch 122: val_accuracy did not improve from 0.48571
#
# Epoch 123: val_accuracy did not improve from 0.48571
#
# Epoch 124: val_accuracy did not improve from 0.48571
#
# Epoch 125: val_accuracy did not improve from 0.48571
#
# Epoch 126: val_accuracy did not improve from 0.48571
#
# Epoch 127: val_accuracy did not improve from 0.48571
#
# Epoch 128: val_accuracy did not improve from 0.48571
#
# Epoch 129: val_accuracy did not improve from 0.48571
#
# Epoch 130: val_accuracy did not improve from 0.48571
#
# Epoch 131: val_accuracy did not improve from 0.48571
#
# Epoch 132: val_accuracy did not improve from 0.48571
#
# Epoch 133: val_accuracy did not improve from 0.48571
#
# Epoch 134: val_accuracy did not improve from 0.48571
#
# Epoch 135: val_accuracy did not improve from 0.48571
#
# Epoch 136: val_accuracy did not improve from 0.48571
#
# Epoch 137: val_accuracy did not improve from 0.48571
#
# Epoch 138: val_accuracy did not improve from 0.48571
#
# Epoch 139: val_accuracy did not improve from 0.48571
#
# Epoch 140: val_accuracy did not improve from 0.48571
#
# Epoch 141: val_accuracy did not improve from 0.48571
#
# Epoch 142: val_accuracy did not improve from 0.48571
#
# Epoch 143: val_accuracy did not improve from 0.48571
#
# Epoch 144: val_accuracy did not improve from 0.48571
#
# Epoch 145: val_accuracy did not improve from 0.48571
#
# Epoch 146: val_accuracy did not improve from 0.48571
#
# Epoch 147: val_accuracy did not improve from 0.48571
#
# Epoch 148: val_accuracy did not improve from 0.48571
#
# Epoch 149: val_accuracy did not improve from 0.48571
#
# Epoch 150: val_accuracy did not improve from 0.48571
#
# Epoch 151: val_accuracy did not improve from 0.48571
#
# Epoch 152: val_accuracy did not improve from 0.48571
#
# Epoch 153: val_accuracy did not improve from 0.48571
#
# Epoch 154: val_accuracy did not improve from 0.48571
#
# Epoch 155: val_accuracy did not improve from 0.48571
#
# Epoch 156: val_accuracy did not improve from 0.48571
#
# Epoch 157: val_accuracy did not improve from 0.48571
#
# Epoch 158: val_accuracy did not improve from 0.48571
#
# Epoch 159: val_accuracy did not improve from 0.48571
#
# Epoch 160: val_accuracy did not improve from 0.48571
#
# Epoch 161: val_accuracy did not improve from 0.48571
#
# Epoch 162: val_accuracy did not improve from 0.48571
#
# Epoch 163: val_accuracy improved from 0.48571 to 0.51429, saving model to /home/metzgeka/ml_project/datasets/symbols/dataset1/chpt/1-chpt.model.keras
#
# Epoch 164: val_accuracy did not improve from 0.51429
#
# Epoch 165: val_accuracy did not improve from 0.51429
#
# Epoch 166: val_accuracy did not improve from 0.51429
#
# Epoch 167: val_accuracy did not improve from 0.51429
#
# Epoch 168: val_accuracy did not improve from 0.51429
#
# Epoch 169: val_accuracy did not improve from 0.51429
#
# Epoch 170: val_accuracy did not improve from 0.51429
#
# Epoch 171: val_accuracy did not improve from 0.51429
#
# Epoch 172: val_accuracy did not improve from 0.51429
#
# Epoch 173: val_accuracy did not improve from 0.51429
#
# Epoch 174: val_accuracy did not improve from 0.51429
#
# Epoch 175: val_accuracy did not improve from 0.51429
#
# Epoch 176: val_accuracy did not improve from 0.51429
#
# Epoch 177: val_accuracy did not improve from 0.51429
#
# Epoch 178: val_accuracy did not improve from 0.51429
#
# Epoch 179: val_accuracy did not improve from 0.51429
#
# Epoch 180: val_accuracy did not improve from 0.51429
#
# Epoch 181: val_accuracy did not improve from 0.51429
#
# Epoch 182: val_accuracy did not improve from 0.51429
#
# Epoch 183: val_accuracy did not improve from 0.51429
#
# Epoch 184: val_accuracy did not improve from 0.51429
#
# Epoch 185: val_accuracy did not improve from 0.51429
#
# Epoch 186: val_accuracy did not improve from 0.51429
#
# Epoch 187: val_accuracy did not improve from 0.51429
#
# Epoch 188: val_accuracy did not improve from 0.51429
#
# Epoch 189: val_accuracy did not improve from 0.51429
#
# Epoch 190: val_accuracy did not improve from 0.51429
#
# Epoch 191: val_accuracy did not improve from 0.51429
#
# Epoch 192: val_accuracy did not improve from 0.51429
#
# Epoch 193: val_accuracy did not improve from 0.51429
#
# Epoch 194: val_accuracy did not improve from 0.51429
#
# Epoch 195: val_accuracy did not improve from 0.51429
#
# Epoch 196: val_accuracy did not improve from 0.51429
#
# Epoch 197: val_accuracy did not improve from 0.51429
#
# Epoch 198: val_accuracy did not improve from 0.51429
#
# Epoch 199: val_accuracy did not improve from 0.51429
#
# Epoch 200: val_accuracy did not improve from 0.51429
#
# Epoch 201: val_accuracy improved from 0.51429 to 0.54286, saving model to /home/metzgeka/ml_project/datasets/symbols/dataset1/chpt/1-chpt.model.keras
#
# Epoch 202: val_accuracy did not improve from 0.54286
#
# Epoch 203: val_accuracy did not improve from 0.54286
#
# Epoch 204: val_accuracy did not improve from 0.54286
#
# Epoch 205: val_accuracy did not improve from 0.54286
#
# Epoch 206: val_accuracy did not improve from 0.54286
#
# Epoch 207: val_accuracy did not improve from 0.54286
#
# Epoch 208: val_accuracy did not improve from 0.54286
#
# Epoch 209: val_accuracy did not improve from 0.54286
#
# Epoch 210: val_accuracy did not improve from 0.54286
#
# Epoch 211: val_accuracy did not improve from 0.54286
#
# Epoch 212: val_accuracy did not improve from 0.54286
#
# Epoch 213: val_accuracy did not improve from 0.54286
#
# Epoch 214: val_accuracy did not improve from 0.54286
#
# Epoch 215: val_accuracy did not improve from 0.54286
#
# Epoch 216: val_accuracy did not improve from 0.54286
#
# Epoch 217: val_accuracy did not improve from 0.54286
#
# Epoch 218: val_accuracy did not improve from 0.54286
#
# Epoch 219: val_accuracy did not improve from 0.54286
#
# Epoch 220: val_accuracy did not improve from 0.54286
#
# Epoch 221: val_accuracy did not improve from 0.54286
#
# Epoch 222: val_accuracy did not improve from 0.54286
#
# Epoch 223: val_accuracy improved from 0.54286 to 0.57143, saving model to /home/metzgeka/ml_project/datasets/symbols/dataset1/chpt/1-chpt.model.keras
#
# Epoch 224: val_accuracy did not improve from 0.57143
#
# Epoch 225: val_accuracy did not improve from 0.57143
#
# Epoch 226: val_accuracy did not improve from 0.57143
#
# Epoch 227: val_accuracy did not improve from 0.57143
#
# Epoch 228: val_accuracy did not improve from 0.57143
#
# Epoch 229: val_accuracy did not improve from 0.57143
#
# Epoch 230: val_accuracy improved from 0.57143 to 0.60000, saving model to /home/metzgeka/ml_project/datasets/symbols/dataset1/chpt/1-chpt.model.keras
#
# Epoch 231: val_accuracy did not improve from 0.60000
#
# Epoch 232: val_accuracy did not improve from 0.60000
#
# Epoch 233: val_accuracy improved from 0.60000 to 0.62857, saving model to /home/metzgeka/ml_project/datasets/symbols/dataset1/chpt/1-chpt.model.keras
#
# Epoch 234: val_accuracy did not improve from 0.62857
#
# Epoch 235: val_accuracy did not improve from 0.62857
#
# Epoch 236: val_accuracy did not improve from 0.62857
#
# Epoch 237: val_accuracy did not improve from 0.62857
#
# Epoch 238: val_accuracy did not improve from 0.62857
#
# Epoch 239: val_accuracy improved from 0.62857 to 0.65714, saving model to /home/metzgeka/ml_project/datasets/symbols/dataset1/chpt/1-chpt.model.keras
#
# Epoch 240: val_accuracy did not improve from 0.65714
#
# Epoch 241: val_accuracy did not improve from 0.65714
#
# Epoch 242: val_accuracy did not improve from 0.65714
#
# Epoch 243: val_accuracy did not improve from 0.65714
#
# Epoch 244: val_accuracy did not improve from 0.65714
#
# Epoch 245: val_accuracy did not improve from 0.65714
#
# Epoch 246: val_accuracy did not improve from 0.65714
#
# Epoch 247: val_accuracy did not improve from 0.65714
#
# Epoch 248: val_accuracy did not improve from 0.65714
#
# Epoch 249: val_accuracy did not improve from 0.65714
#
# Epoch 250: val_accuracy did not improve from 0.65714
#
# Epoch 251: val_accuracy did not improve from 0.65714
#
# Epoch 252: val_accuracy did not improve from 0.65714
#
# Epoch 253: val_accuracy did not improve from 0.65714
#
# Epoch 254: val_accuracy did not improve from 0.65714
#
# Epoch 255: val_accuracy did not improve from 0.65714
#
# Epoch 256: val_accuracy did not improve from 0.65714
#
# Epoch 257: val_accuracy did not improve from 0.65714
#
# Epoch 258: val_accuracy did not improve from 0.65714
#
# Epoch 259: val_accuracy did not improve from 0.65714
#
# Epoch 260: val_accuracy did not improve from 0.65714
#
# Epoch 261: val_accuracy improved from 0.65714 to 0.68571, saving model to /home/metzgeka/ml_project/datasets/symbols/dataset1/chpt/1-chpt.model.keras
#
# Epoch 262: val_accuracy did not improve from 0.68571
#
# Epoch 263: val_accuracy did not improve from 0.68571
#
# Epoch 264: val_accuracy did not improve from 0.68571
#
# Epoch 265: val_accuracy did not improve from 0.68571
#
# Epoch 266: val_accuracy did not improve from 0.68571
#
# Epoch 267: val_accuracy did not improve from 0.68571
#
# Epoch 268: val_accuracy did not improve from 0.68571
#
# Epoch 269: val_accuracy did not improve from 0.68571
#
# Epoch 270: val_accuracy did not improve from 0.68571
#
# Epoch 271: val_accuracy did not improve from 0.68571
#
# Epoch 272: val_accuracy did not improve from 0.68571
#
# Epoch 273: val_accuracy did not improve from 0.68571
#
# Epoch 274: val_accuracy did not improve from 0.68571
#
# Epoch 275: val_accuracy did not improve from 0.68571
#
# Epoch 276: val_accuracy did not improve from 0.68571
#
# Epoch 277: val_accuracy did not improve from 0.68571
#
# Epoch 278: val_accuracy did not improve from 0.68571
#
# Epoch 279: val_accuracy did not improve from 0.68571
#
# Epoch 280: val_accuracy did not improve from 0.68571
#
# Epoch 281: val_accuracy did not improve from 0.68571
#
# Epoch 282: val_accuracy did not improve from 0.68571
#
# Epoch 283: val_accuracy did not improve from 0.68571
#
# Epoch 284: val_accuracy did not improve from 0.68571
#
# Epoch 285: val_accuracy did not improve from 0.68571
#
# Epoch 286: val_accuracy did not improve from 0.68571
#
# Epoch 287: val_accuracy did not improve from 0.68571
#
# Epoch 288: val_accuracy did not improve from 0.68571
#
# Epoch 289: val_accuracy did not improve from 0.68571
#
# Epoch 290: val_accuracy did not improve from 0.68571
#
# Epoch 291: val_accuracy did not improve from 0.68571
#
# Epoch 292: val_accuracy did not improve from 0.68571
#
# Epoch 293: val_accuracy did not improve from 0.68571
#
# Epoch 294: val_accuracy did not improve from 0.68571
#
# Epoch 295: val_accuracy did not improve from 0.68571
#
# Epoch 296: val_accuracy did not improve from 0.68571
#
# Epoch 297: val_accuracy did not improve from 0.68571
#
# Epoch 298: val_accuracy did not improve from 0.68571
#
# Epoch 299: val_accuracy did not improve from 0.68571
#
# Epoch 300: val_accuracy did not improve from 0.68571
# #################################################
#
# Training 2 with image size [32, 28] and [128, 32, 16, 4] neurons per layer
#
# Epoch 1: val_accuracy improved from -inf to 0.25714, saving model to /home/metzgeka/ml_project/datasets/symbols/dataset1/chpt/2-chpt.model.keras
#
# Epoch 2: val_accuracy did not improve from 0.25714
#
# Epoch 3: val_accuracy did not improve from 0.25714
#
# Epoch 4: val_accuracy did not improve from 0.25714
#
# Epoch 5: val_accuracy did not improve from 0.25714
#
# Epoch 6: val_accuracy improved from 0.25714 to 0.34286, saving model to /home/metzgeka/ml_project/datasets/symbols/dataset1/chpt/2-chpt.model.keras
#
# Epoch 7: val_accuracy did not improve from 0.34286
#
# Epoch 8: val_accuracy did not improve from 0.34286
#
# Epoch 9: val_accuracy did not improve from 0.34286
#
# Epoch 10: val_accuracy did not improve from 0.34286
#
# Epoch 11: val_accuracy did not improve from 0.34286
#
# Epoch 12: val_accuracy did not improve from 0.34286
#
# Epoch 13: val_accuracy did not improve from 0.34286
#
# Epoch 14: val_accuracy did not improve from 0.34286
#
# Epoch 15: val_accuracy did not improve from 0.34286
#
# Epoch 16: val_accuracy did not improve from 0.34286
#
# Epoch 17: val_accuracy did not improve from 0.34286
#
# Epoch 18: val_accuracy did not improve from 0.34286
#
# Epoch 19: val_accuracy did not improve from 0.34286
#
# Epoch 20: val_accuracy did not improve from 0.34286
#
# Epoch 21: val_accuracy did not improve from 0.34286
#
# Epoch 22: val_accuracy did not improve from 0.34286
#
# Epoch 23: val_accuracy did not improve from 0.34286
#
# Epoch 24: val_accuracy did not improve from 0.34286
#
# Epoch 25: val_accuracy did not improve from 0.34286
#
# Epoch 26: val_accuracy did not improve from 0.34286
#
# Epoch 27: val_accuracy did not improve from 0.34286
#
# Epoch 28: val_accuracy did not improve from 0.34286
#
# Epoch 29: val_accuracy did not improve from 0.34286
#
# Epoch 30: val_accuracy did not improve from 0.34286
#
# Epoch 31: val_accuracy did not improve from 0.34286
#
# Epoch 32: val_accuracy did not improve from 0.34286
#
# Epoch 33: val_accuracy did not improve from 0.34286
#
# Epoch 34: val_accuracy did not improve from 0.34286
#
# Epoch 35: val_accuracy did not improve from 0.34286
#
# Epoch 36: val_accuracy did not improve from 0.34286
#
# Epoch 37: val_accuracy did not improve from 0.34286
#
# Epoch 38: val_accuracy did not improve from 0.34286
#
# Epoch 39: val_accuracy did not improve from 0.34286
#
# Epoch 40: val_accuracy did not improve from 0.34286
#
# Epoch 41: val_accuracy did not improve from 0.34286
#
# Epoch 42: val_accuracy did not improve from 0.34286
#
# Epoch 43: val_accuracy improved from 0.34286 to 0.42857, saving model to /home/metzgeka/ml_project/datasets/symbols/dataset1/chpt/2-chpt.model.keras
#
# Epoch 44: val_accuracy did not improve from 0.42857
#
# Epoch 45: val_accuracy did not improve from 0.42857
#
# Epoch 46: val_accuracy did not improve from 0.42857
#
# Epoch 47: val_accuracy did not improve from 0.42857
#
# Epoch 48: val_accuracy did not improve from 0.42857
#
# Epoch 49: val_accuracy did not improve from 0.42857
#
# Epoch 50: val_accuracy did not improve from 0.42857
#
# Epoch 51: val_accuracy did not improve from 0.42857
#
# Epoch 52: val_accuracy did not improve from 0.42857
#
# Epoch 53: val_accuracy did not improve from 0.42857
#
# Epoch 54: val_accuracy did not improve from 0.42857
#
# Epoch 55: val_accuracy did not improve from 0.42857
#
# Epoch 56: val_accuracy did not improve from 0.42857
#
# Epoch 57: val_accuracy did not improve from 0.42857
#
# Epoch 58: val_accuracy did not improve from 0.42857
#
# Epoch 59: val_accuracy did not improve from 0.42857
#
# Epoch 60: val_accuracy did not improve from 0.42857
#
# Epoch 61: val_accuracy did not improve from 0.42857
#
# Epoch 62: val_accuracy improved from 0.42857 to 0.48571, saving model to /home/metzgeka/ml_project/datasets/symbols/dataset1/chpt/2-chpt.model.keras
#
# Epoch 63: val_accuracy did not improve from 0.48571
#
# Epoch 64: val_accuracy did not improve from 0.48571
#
# Epoch 65: val_accuracy did not improve from 0.48571
#
# Epoch 66: val_accuracy did not improve from 0.48571
#
# Epoch 67: val_accuracy did not improve from 0.48571
#
# Epoch 68: val_accuracy did not improve from 0.48571
#
# Epoch 69: val_accuracy did not improve from 0.48571
#
# Epoch 70: val_accuracy did not improve from 0.48571
#
# Epoch 71: val_accuracy did not improve from 0.48571
#
# Epoch 72: val_accuracy did not improve from 0.48571
#
# Epoch 73: val_accuracy did not improve from 0.48571
#
# Epoch 74: val_accuracy did not improve from 0.48571
#
# Epoch 75: val_accuracy did not improve from 0.48571
#
# Epoch 76: val_accuracy did not improve from 0.48571
#
# Epoch 77: val_accuracy did not improve from 0.48571
#
# Epoch 78: val_accuracy did not improve from 0.48571
#
# Epoch 79: val_accuracy did not improve from 0.48571
#
# Epoch 80: val_accuracy did not improve from 0.48571
#
# Epoch 81: val_accuracy did not improve from 0.48571
#
# Epoch 82: val_accuracy did not improve from 0.48571
#
# Epoch 83: val_accuracy did not improve from 0.48571
#
# Epoch 84: val_accuracy did not improve from 0.48571
#
# Epoch 85: val_accuracy did not improve from 0.48571
#
# Epoch 86: val_accuracy did not improve from 0.48571
#
# Epoch 87: val_accuracy improved from 0.48571 to 0.57143, saving model to /home/metzgeka/ml_project/datasets/symbols/dataset1/chpt/2-chpt.model.keras
#
# Epoch 88: val_accuracy did not improve from 0.57143
#
# Epoch 89: val_accuracy did not improve from 0.57143
#
# Epoch 90: val_accuracy did not improve from 0.57143
#
# Epoch 91: val_accuracy did not improve from 0.57143
#
# Epoch 92: val_accuracy did not improve from 0.57143
#
# Epoch 93: val_accuracy did not improve from 0.57143
#
# Epoch 94: val_accuracy did not improve from 0.57143
#
# Epoch 95: val_accuracy did not improve from 0.57143
#
# Epoch 96: val_accuracy did not improve from 0.57143
#
# Epoch 97: val_accuracy did not improve from 0.57143
#
# Epoch 98: val_accuracy did not improve from 0.57143
#
# Epoch 99: val_accuracy did not improve from 0.57143
#
# Epoch 100: val_accuracy did not improve from 0.57143
#
# Epoch 101: val_accuracy did not improve from 0.57143
#
# Epoch 102: val_accuracy did not improve from 0.57143
#
# Epoch 103: val_accuracy did not improve from 0.57143
#
# Epoch 104: val_accuracy did not improve from 0.57143
#
# Epoch 105: val_accuracy did not improve from 0.57143
#
# Epoch 106: val_accuracy did not improve from 0.57143
#
# Epoch 107: val_accuracy did not improve from 0.57143
#
# Epoch 108: val_accuracy did not improve from 0.57143
#
# Epoch 109: val_accuracy did not improve from 0.57143
#
# Epoch 110: val_accuracy did not improve from 0.57143
#
# Epoch 111: val_accuracy did not improve from 0.57143
#
# Epoch 112: val_accuracy did not improve from 0.57143
#
# Epoch 113: val_accuracy did not improve from 0.57143
#
# Epoch 114: val_accuracy did not improve from 0.57143
#
# Epoch 115: val_accuracy did not improve from 0.57143
#
# Epoch 116: val_accuracy did not improve from 0.57143
#
# Epoch 117: val_accuracy did not improve from 0.57143
#
# Epoch 118: val_accuracy did not improve from 0.57143
#
# Epoch 119: val_accuracy did not improve from 0.57143
#
# Epoch 120: val_accuracy did not improve from 0.57143
#
# Epoch 121: val_accuracy did not improve from 0.57143
#
# Epoch 122: val_accuracy did not improve from 0.57143
#
# Epoch 123: val_accuracy did not improve from 0.57143
#
# Epoch 124: val_accuracy did not improve from 0.57143
#
# Epoch 125: val_accuracy did not improve from 0.57143
#
# Epoch 126: val_accuracy did not improve from 0.57143
#
# Epoch 127: val_accuracy did not improve from 0.57143
#
# Epoch 128: val_accuracy did not improve from 0.57143
#
# Epoch 129: val_accuracy did not improve from 0.57143
#
# Epoch 130: val_accuracy did not improve from 0.57143
#
# Epoch 131: val_accuracy did not improve from 0.57143
#
# Epoch 132: val_accuracy did not improve from 0.57143
#
# Epoch 133: val_accuracy did not improve from 0.57143
#
# Epoch 134: val_accuracy did not improve from 0.57143
#
# Epoch 135: val_accuracy did not improve from 0.57143
#
# Epoch 136: val_accuracy did not improve from 0.57143
#
# Epoch 137: val_accuracy did not improve from 0.57143
#
# Epoch 138: val_accuracy did not improve from 0.57143
#
# Epoch 139: val_accuracy did not improve from 0.57143
#
# Epoch 140: val_accuracy did not improve from 0.57143
#
# Epoch 141: val_accuracy did not improve from 0.57143
#
# Epoch 142: val_accuracy did not improve from 0.57143
#
# Epoch 143: val_accuracy did not improve from 0.57143
#
# Epoch 144: val_accuracy did not improve from 0.57143
#
# Epoch 145: val_accuracy did not improve from 0.57143
#
# Epoch 146: val_accuracy did not improve from 0.57143
#
# Epoch 147: val_accuracy did not improve from 0.57143
#
# Epoch 148: val_accuracy did not improve from 0.57143
#
# Epoch 149: val_accuracy did not improve from 0.57143
#
# Epoch 150: val_accuracy did not improve from 0.57143
#
# Epoch 151: val_accuracy did not improve from 0.57143
#
# Epoch 152: val_accuracy did not improve from 0.57143
#
# Epoch 153: val_accuracy did not improve from 0.57143
#
# Epoch 154: val_accuracy did not improve from 0.57143
#
# Epoch 155: val_accuracy did not improve from 0.57143
#
# Epoch 156: val_accuracy did not improve from 0.57143
#
# Epoch 157: val_accuracy did not improve from 0.57143
#
# Epoch 158: val_accuracy did not improve from 0.57143
#
# Epoch 159: val_accuracy did not improve from 0.57143
#
# Epoch 160: val_accuracy did not improve from 0.57143
#
# Epoch 161: val_accuracy did not improve from 0.57143
#
# Epoch 162: val_accuracy did not improve from 0.57143
#
# Epoch 163: val_accuracy did not improve from 0.57143
#
# Epoch 164: val_accuracy did not improve from 0.57143
#
# Epoch 165: val_accuracy did not improve from 0.57143
#
# Epoch 166: val_accuracy did not improve from 0.57143
#
# Epoch 167: val_accuracy did not improve from 0.57143
#
# Epoch 168: val_accuracy did not improve from 0.57143
#
# Epoch 169: val_accuracy did not improve from 0.57143
#
# Epoch 170: val_accuracy did not improve from 0.57143
#
# Epoch 171: val_accuracy did not improve from 0.57143
#
# Epoch 172: val_accuracy did not improve from 0.57143
#
# Epoch 173: val_accuracy did not improve from 0.57143
#
# Epoch 174: val_accuracy did not improve from 0.57143
#
# Epoch 175: val_accuracy did not improve from 0.57143
#
# Epoch 176: val_accuracy did not improve from 0.57143
#
# Epoch 177: val_accuracy did not improve from 0.57143
#
# Epoch 178: val_accuracy did not improve from 0.57143
#
# Epoch 179: val_accuracy did not improve from 0.57143
#
# Epoch 180: val_accuracy did not improve from 0.57143
#
# Epoch 181: val_accuracy did not improve from 0.57143
#
# Epoch 182: val_accuracy did not improve from 0.57143
#
# Epoch 183: val_accuracy did not improve from 0.57143
#
# Epoch 184: val_accuracy did not improve from 0.57143
#
# Epoch 185: val_accuracy did not improve from 0.57143
#
# Epoch 186: val_accuracy did not improve from 0.57143
#
# Epoch 187: val_accuracy did not improve from 0.57143
#
# Epoch 188: val_accuracy did not improve from 0.57143
#
# Epoch 189: val_accuracy did not improve from 0.57143
#
# Epoch 190: val_accuracy did not improve from 0.57143
#
# Epoch 191: val_accuracy did not improve from 0.57143
#
# Epoch 192: val_accuracy did not improve from 0.57143
#
# Epoch 193: val_accuracy did not improve from 0.57143
#
# Epoch 194: val_accuracy did not improve from 0.57143
#
# Epoch 195: val_accuracy did not improve from 0.57143
#
# Epoch 196: val_accuracy did not improve from 0.57143
#
# Epoch 197: val_accuracy did not improve from 0.57143
#
# Epoch 198: val_accuracy did not improve from 0.57143
#
# Epoch 199: val_accuracy did not improve from 0.57143
#
# Epoch 200: val_accuracy did not improve from 0.57143
#
# Epoch 201: val_accuracy did not improve from 0.57143
#
# Epoch 202: val_accuracy did not improve from 0.57143
#
# Epoch 203: val_accuracy did not improve from 0.57143
#
# Epoch 204: val_accuracy did not improve from 0.57143
#
# Epoch 205: val_accuracy did not improve from 0.57143
#
# Epoch 206: val_accuracy did not improve from 0.57143
#
# Epoch 207: val_accuracy did not improve from 0.57143
#
# Epoch 208: val_accuracy did not improve from 0.57143
#
# Epoch 209: val_accuracy did not improve from 0.57143
#
# Epoch 210: val_accuracy did not improve from 0.57143
#
# Epoch 211: val_accuracy did not improve from 0.57143
#
# Epoch 212: val_accuracy did not improve from 0.57143
#
# Epoch 213: val_accuracy did not improve from 0.57143
#
# Epoch 214: val_accuracy did not improve from 0.57143
#
# Epoch 215: val_accuracy did not improve from 0.57143
#
# Epoch 216: val_accuracy did not improve from 0.57143
#
# Epoch 217: val_accuracy did not improve from 0.57143
#
# Epoch 218: val_accuracy did not improve from 0.57143
#
# Epoch 219: val_accuracy did not improve from 0.57143
#
# Epoch 220: val_accuracy did not improve from 0.57143
#
# Epoch 221: val_accuracy did not improve from 0.57143
#
# Epoch 222: val_accuracy did not improve from 0.57143
#
# Epoch 223: val_accuracy did not improve from 0.57143
#
# Epoch 224: val_accuracy did not improve from 0.57143
#
# Epoch 225: val_accuracy did not improve from 0.57143
#
# Epoch 226: val_accuracy did not improve from 0.57143
#
# Epoch 227: val_accuracy did not improve from 0.57143
#
# Epoch 228: val_accuracy did not improve from 0.57143
#
# Epoch 229: val_accuracy did not improve from 0.57143
#
# Epoch 230: val_accuracy did not improve from 0.57143
#
# Epoch 231: val_accuracy did not improve from 0.57143
#
# Epoch 232: val_accuracy did not improve from 0.57143
#
# Epoch 233: val_accuracy did not improve from 0.57143
#
# Epoch 234: val_accuracy did not improve from 0.57143
#
# Epoch 235: val_accuracy did not improve from 0.57143
#
# Epoch 236: val_accuracy did not improve from 0.57143
#
# Epoch 237: val_accuracy did not improve from 0.57143
#
# Epoch 238: val_accuracy did not improve from 0.57143
#
# Epoch 239: val_accuracy did not improve from 0.57143
#
# Epoch 240: val_accuracy did not improve from 0.57143
#
# Epoch 241: val_accuracy did not improve from 0.57143
#
# Epoch 242: val_accuracy did not improve from 0.57143
#
# Epoch 243: val_accuracy did not improve from 0.57143
#
# Epoch 244: val_accuracy did not improve from 0.57143
#
# Epoch 245: val_accuracy did not improve from 0.57143
#
# Epoch 246: val_accuracy did not improve from 0.57143
#
# Epoch 247: val_accuracy did not improve from 0.57143
#
# Epoch 248: val_accuracy did not improve from 0.57143
#
# Epoch 249: val_accuracy did not improve from 0.57143
#
# Epoch 250: val_accuracy did not improve from 0.57143
#
# Epoch 251: val_accuracy did not improve from 0.57143
#
# Epoch 252: val_accuracy did not improve from 0.57143
#
# Epoch 253: val_accuracy did not improve from 0.57143
#
# Epoch 254: val_accuracy did not improve from 0.57143
#
# Epoch 255: val_accuracy did not improve from 0.57143
#
# Epoch 256: val_accuracy did not improve from 0.57143
#
# Epoch 257: val_accuracy did not improve from 0.57143
#
# Epoch 258: val_accuracy did not improve from 0.57143
#
# Epoch 259: val_accuracy did not improve from 0.57143
#
# Epoch 260: val_accuracy did not improve from 0.57143
#
# Epoch 261: val_accuracy did not improve from 0.57143
#
# Epoch 262: val_accuracy did not improve from 0.57143
#
# Epoch 263: val_accuracy did not improve from 0.57143
#
# Epoch 264: val_accuracy did not improve from 0.57143
#
# Epoch 265: val_accuracy did not improve from 0.57143
#
# Epoch 266: val_accuracy did not improve from 0.57143
#
# Epoch 267: val_accuracy did not improve from 0.57143
#
# Epoch 268: val_accuracy did not improve from 0.57143
#
# Epoch 269: val_accuracy did not improve from 0.57143
#
# Epoch 270: val_accuracy did not improve from 0.57143
#
# Epoch 271: val_accuracy did not improve from 0.57143
#
# Epoch 272: val_accuracy did not improve from 0.57143
#
# Epoch 273: val_accuracy did not improve from 0.57143
#
# Epoch 274: val_accuracy did not improve from 0.57143
#
# Epoch 275: val_accuracy did not improve from 0.57143
#
# Epoch 276: val_accuracy did not improve from 0.57143
#
# Epoch 277: val_accuracy did not improve from 0.57143
#
# Epoch 278: val_accuracy did not improve from 0.57143
#
# Epoch 279: val_accuracy did not improve from 0.57143
#
# Epoch 280: val_accuracy did not improve from 0.57143
#
# Epoch 281: val_accuracy did not improve from 0.57143
#
# Epoch 282: val_accuracy did not improve from 0.57143
#
# Epoch 283: val_accuracy did not improve from 0.57143
#
# Epoch 284: val_accuracy did not improve from 0.57143
#
# Epoch 285: val_accuracy did not improve from 0.57143
#
# Epoch 286: val_accuracy did not improve from 0.57143
#
# Epoch 287: val_accuracy did not improve from 0.57143
#
# Epoch 288: val_accuracy did not improve from 0.57143
#
# Epoch 289: val_accuracy did not improve from 0.57143
#
# Epoch 290: val_accuracy did not improve from 0.57143
#
# Epoch 291: val_accuracy did not improve from 0.57143
#
# Epoch 292: val_accuracy did not improve from 0.57143
#
# Epoch 293: val_accuracy did not improve from 0.57143
#
# Epoch 294: val_accuracy did not improve from 0.57143
#
# Epoch 295: val_accuracy did not improve from 0.57143
#
# Epoch 296: val_accuracy did not improve from 0.57143
#
# Epoch 297: val_accuracy did not improve from 0.57143
#
# Epoch 298: val_accuracy did not improve from 0.57143
#
# Epoch 299: val_accuracy did not improve from 0.57143
#
# Epoch 300: val_accuracy did not improve from 0.57143
# #################################################
#
# Training 3 with image size [32, 28] and [64, 32, 16, 4] neurons per layer
#
# Epoch 1: val_accuracy improved from -inf to 0.31429, saving model to /home/metzgeka/ml_project/datasets/symbols/dataset1/chpt/3-chpt.model.keras
#
# Epoch 2: val_accuracy did not improve from 0.31429
#
# Epoch 3: val_accuracy did not improve from 0.31429
#
# Epoch 4: val_accuracy did not improve from 0.31429
#
# Epoch 5: val_accuracy did not improve from 0.31429
#
# Epoch 6: val_accuracy did not improve from 0.31429
#
# Epoch 7: val_accuracy did not improve from 0.31429
#
# Epoch 8: val_accuracy did not improve from 0.31429
#
# Epoch 9: val_accuracy did not improve from 0.31429
#
# Epoch 10: val_accuracy did not improve from 0.31429
#
# Epoch 11: val_accuracy did not improve from 0.31429
#
# Epoch 12: val_accuracy improved from 0.31429 to 0.34286, saving model to /home/metzgeka/ml_project/datasets/symbols/dataset1/chpt/3-chpt.model.keras
#
# Epoch 13: val_accuracy did not improve from 0.34286
#
# Epoch 14: val_accuracy did not improve from 0.34286
#
# Epoch 15: val_accuracy did not improve from 0.34286
#
# Epoch 16: val_accuracy did not improve from 0.34286
#
# Epoch 17: val_accuracy did not improve from 0.34286
#
# Epoch 18: val_accuracy did not improve from 0.34286
#
# Epoch 19: val_accuracy did not improve from 0.34286
#
# Epoch 20: val_accuracy did not improve from 0.34286
#
# Epoch 21: val_accuracy did not improve from 0.34286
#
# Epoch 22: val_accuracy did not improve from 0.34286
#
# Epoch 23: val_accuracy did not improve from 0.34286
#
# Epoch 24: val_accuracy did not improve from 0.34286
#
# Epoch 25: val_accuracy did not improve from 0.34286
#
# Epoch 26: val_accuracy did not improve from 0.34286
#
# Epoch 27: val_accuracy did not improve from 0.34286
#
# Epoch 28: val_accuracy did not improve from 0.34286
#
# Epoch 29: val_accuracy did not improve from 0.34286
#
# Epoch 30: val_accuracy did not improve from 0.34286
#
# Epoch 31: val_accuracy did not improve from 0.34286
#
# Epoch 32: val_accuracy improved from 0.34286 to 0.42857, saving model to /home/metzgeka/ml_project/datasets/symbols/dataset1/chpt/3-chpt.model.keras
#
# Epoch 33: val_accuracy did not improve from 0.42857
#
# Epoch 34: val_accuracy did not improve from 0.42857
#
# Epoch 35: val_accuracy did not improve from 0.42857
#
# Epoch 36: val_accuracy did not improve from 0.42857
#
# Epoch 37: val_accuracy did not improve from 0.42857
#
# Epoch 38: val_accuracy did not improve from 0.42857
#
# Epoch 39: val_accuracy did not improve from 0.42857
#
# Epoch 40: val_accuracy did not improve from 0.42857
#
# Epoch 41: val_accuracy did not improve from 0.42857
#
# Epoch 42: val_accuracy did not improve from 0.42857
#
# Epoch 43: val_accuracy did not improve from 0.42857
#
# Epoch 44: val_accuracy did not improve from 0.42857
#
# Epoch 45: val_accuracy did not improve from 0.42857
#
# Epoch 46: val_accuracy did not improve from 0.42857
#
# Epoch 47: val_accuracy did not improve from 0.42857
#
# Epoch 48: val_accuracy did not improve from 0.42857
#
# Epoch 49: val_accuracy did not improve from 0.42857
#
# Epoch 50: val_accuracy did not improve from 0.42857
#
# Epoch 51: val_accuracy did not improve from 0.42857
#
# Epoch 52: val_accuracy did not improve from 0.42857
#
# Epoch 53: val_accuracy did not improve from 0.42857
#
# Epoch 54: val_accuracy did not improve from 0.42857
#
# Epoch 55: val_accuracy did not improve from 0.42857
#
# Epoch 56: val_accuracy did not improve from 0.42857
#
# Epoch 57: val_accuracy improved from 0.42857 to 0.48571, saving model to /home/metzgeka/ml_project/datasets/symbols/dataset1/chpt/3-chpt.model.keras
#
# Epoch 58: val_accuracy did not improve from 0.48571
#
# Epoch 59: val_accuracy did not improve from 0.48571
#
# Epoch 60: val_accuracy did not improve from 0.48571
#
# Epoch 61: val_accuracy did not improve from 0.48571
#
# Epoch 62: val_accuracy did not improve from 0.48571
#
# Epoch 63: val_accuracy did not improve from 0.48571
#
# Epoch 64: val_accuracy did not improve from 0.48571
#
# Epoch 65: val_accuracy did not improve from 0.48571
#
# Epoch 66: val_accuracy improved from 0.48571 to 0.60000, saving model to /home/metzgeka/ml_project/datasets/symbols/dataset1/chpt/3-chpt.model.keras
#
# Epoch 67: val_accuracy did not improve from 0.60000
#
# Epoch 68: val_accuracy did not improve from 0.60000
#
# Epoch 69: val_accuracy did not improve from 0.60000
#
# Epoch 70: val_accuracy did not improve from 0.60000
#
# Epoch 71: val_accuracy did not improve from 0.60000
#
# Epoch 72: val_accuracy did not improve from 0.60000
#
# Epoch 73: val_accuracy did not improve from 0.60000
#
# Epoch 74: val_accuracy did not improve from 0.60000
#
# Epoch 75: val_accuracy did not improve from 0.60000
#
# Epoch 76: val_accuracy did not improve from 0.60000
#
# Epoch 77: val_accuracy did not improve from 0.60000
#
# Epoch 78: val_accuracy did not improve from 0.60000
#
# Epoch 79: val_accuracy did not improve from 0.60000
#
# Epoch 80: val_accuracy did not improve from 0.60000
#
# Epoch 81: val_accuracy did not improve from 0.60000
#
# Epoch 82: val_accuracy did not improve from 0.60000
#
# Epoch 83: val_accuracy did not improve from 0.60000
#
# Epoch 84: val_accuracy did not improve from 0.60000
#
# Epoch 85: val_accuracy did not improve from 0.60000
#
# Epoch 86: val_accuracy did not improve from 0.60000
#
# Epoch 87: val_accuracy did not improve from 0.60000
#
# Epoch 88: val_accuracy did not improve from 0.60000
#
# Epoch 89: val_accuracy did not improve from 0.60000
#
# Epoch 90: val_accuracy did not improve from 0.60000
#
# Epoch 91: val_accuracy did not improve from 0.60000
#
# Epoch 92: val_accuracy did not improve from 0.60000
#
# Epoch 93: val_accuracy did not improve from 0.60000
#
# Epoch 94: val_accuracy did not improve from 0.60000
#
# Epoch 95: val_accuracy did not improve from 0.60000
#
# Epoch 96: val_accuracy did not improve from 0.60000
#
# Epoch 97: val_accuracy did not improve from 0.60000
#
# Epoch 98: val_accuracy improved from 0.60000 to 0.62857, saving model to /home/metzgeka/ml_project/datasets/symbols/dataset1/chpt/3-chpt.model.keras
#
# Epoch 99: val_accuracy did not improve from 0.62857
#
# Epoch 100: val_accuracy did not improve from 0.62857
#
# Epoch 101: val_accuracy did not improve from 0.62857
#
# Epoch 102: val_accuracy did not improve from 0.62857
#
# Epoch 103: val_accuracy did not improve from 0.62857
#
# Epoch 104: val_accuracy did not improve from 0.62857
#
# Epoch 105: val_accuracy did not improve from 0.62857
#
# Epoch 106: val_accuracy did not improve from 0.62857
#
# Epoch 107: val_accuracy did not improve from 0.62857
#
# Epoch 108: val_accuracy did not improve from 0.62857
#
# Epoch 109: val_accuracy did not improve from 0.62857
#
# Epoch 110: val_accuracy did not improve from 0.62857
#
# Epoch 111: val_accuracy did not improve from 0.62857
#
# Epoch 112: val_accuracy improved from 0.62857 to 0.65714, saving model to /home/metzgeka/ml_project/datasets/symbols/dataset1/chpt/3-chpt.model.keras
#
# Epoch 113: val_accuracy did not improve from 0.65714
#
# Epoch 114: val_accuracy did not improve from 0.65714
#
# Epoch 115: val_accuracy did not improve from 0.65714
#
# Epoch 116: val_accuracy did not improve from 0.65714
#
# Epoch 117: val_accuracy did not improve from 0.65714
#
# Epoch 118: val_accuracy did not improve from 0.65714
#
# Epoch 119: val_accuracy did not improve from 0.65714
#
# Epoch 120: val_accuracy did not improve from 0.65714
#
# Epoch 121: val_accuracy did not improve from 0.65714
#
# Epoch 122: val_accuracy did not improve from 0.65714
#
# Epoch 123: val_accuracy did not improve from 0.65714
#
# Epoch 124: val_accuracy did not improve from 0.65714
#
# Epoch 125: val_accuracy did not improve from 0.65714
#
# Epoch 126: val_accuracy did not improve from 0.65714
#
# Epoch 127: val_accuracy did not improve from 0.65714
#
# Epoch 128: val_accuracy did not improve from 0.65714
#
# Epoch 129: val_accuracy did not improve from 0.65714
#
# Epoch 130: val_accuracy did not improve from 0.65714
#
# Epoch 131: val_accuracy did not improve from 0.65714
#
# Epoch 132: val_accuracy did not improve from 0.65714
#
# Epoch 133: val_accuracy did not improve from 0.65714
#
# Epoch 134: val_accuracy did not improve from 0.65714
#
# Epoch 135: val_accuracy did not improve from 0.65714
#
# Epoch 136: val_accuracy did not improve from 0.65714
#
# Epoch 137: val_accuracy did not improve from 0.65714
#
# Epoch 138: val_accuracy did not improve from 0.65714
#
# Epoch 139: val_accuracy did not improve from 0.65714
#
# Epoch 140: val_accuracy did not improve from 0.65714
#
# Epoch 141: val_accuracy did not improve from 0.65714
#
# Epoch 142: val_accuracy did not improve from 0.65714
#
# Epoch 143: val_accuracy did not improve from 0.65714
#
# Epoch 144: val_accuracy did not improve from 0.65714
#
# Epoch 145: val_accuracy did not improve from 0.65714
#
# Epoch 146: val_accuracy did not improve from 0.65714
#
# Epoch 147: val_accuracy did not improve from 0.65714
#
# Epoch 148: val_accuracy did not improve from 0.65714
#
# Epoch 149: val_accuracy did not improve from 0.65714
#
# Epoch 150: val_accuracy did not improve from 0.65714
#
# Epoch 151: val_accuracy did not improve from 0.65714
#
# Epoch 152: val_accuracy did not improve from 0.65714
#
# Epoch 153: val_accuracy did not improve from 0.65714
#
# Epoch 154: val_accuracy did not improve from 0.65714
#
# Epoch 155: val_accuracy did not improve from 0.65714
#
# Epoch 156: val_accuracy did not improve from 0.65714
#
# Epoch 157: val_accuracy did not improve from 0.65714
#
# Epoch 158: val_accuracy did not improve from 0.65714
#
# Epoch 159: val_accuracy did not improve from 0.65714
#
# Epoch 160: val_accuracy improved from 0.65714 to 0.68571, saving model to /home/metzgeka/ml_project/datasets/symbols/dataset1/chpt/3-chpt.model.keras
#
# Epoch 161: val_accuracy did not improve from 0.68571
#
# Epoch 162: val_accuracy did not improve from 0.68571
#
# Epoch 163: val_accuracy did not improve from 0.68571
#
# Epoch 164: val_accuracy did not improve from 0.68571
#
# Epoch 165: val_accuracy did not improve from 0.68571
#
# Epoch 166: val_accuracy did not improve from 0.68571
#
# Epoch 167: val_accuracy did not improve from 0.68571
#
# Epoch 168: val_accuracy did not improve from 0.68571
#
# Epoch 169: val_accuracy did not improve from 0.68571
#
# Epoch 170: val_accuracy did not improve from 0.68571
#
# Epoch 171: val_accuracy did not improve from 0.68571
#
# Epoch 172: val_accuracy did not improve from 0.68571
#
# Epoch 173: val_accuracy did not improve from 0.68571
#
# Epoch 174: val_accuracy did not improve from 0.68571
#
# Epoch 175: val_accuracy did not improve from 0.68571
#
# Epoch 176: val_accuracy did not improve from 0.68571
#
# Epoch 177: val_accuracy did not improve from 0.68571
#
# Epoch 178: val_accuracy did not improve from 0.68571
#
# Epoch 179: val_accuracy did not improve from 0.68571
#
# Epoch 180: val_accuracy did not improve from 0.68571
#
# Epoch 181: val_accuracy did not improve from 0.68571
#
# Epoch 182: val_accuracy did not improve from 0.68571
#
# Epoch 183: val_accuracy did not improve from 0.68571
#
# Epoch 184: val_accuracy did not improve from 0.68571
#
# Epoch 185: val_accuracy did not improve from 0.68571
#
# Epoch 186: val_accuracy did not improve from 0.68571
#
# Epoch 187: val_accuracy did not improve from 0.68571
#
# Epoch 188: val_accuracy did not improve from 0.68571
#
# Epoch 189: val_accuracy did not improve from 0.68571
#
# Epoch 190: val_accuracy did not improve from 0.68571
#
# Epoch 191: val_accuracy did not improve from 0.68571
#
# Epoch 192: val_accuracy did not improve from 0.68571
#
# Epoch 193: val_accuracy did not improve from 0.68571
#
# Epoch 194: val_accuracy did not improve from 0.68571
#
# Epoch 195: val_accuracy did not improve from 0.68571
#
# Epoch 196: val_accuracy did not improve from 0.68571
#
# Epoch 197: val_accuracy did not improve from 0.68571
#
# Epoch 198: val_accuracy did not improve from 0.68571
#
# Epoch 199: val_accuracy did not improve from 0.68571
#
# Epoch 200: val_accuracy did not improve from 0.68571
#
# Epoch 201: val_accuracy did not improve from 0.68571
#
# Epoch 202: val_accuracy did not improve from 0.68571
#
# Epoch 203: val_accuracy did not improve from 0.68571
#
# Epoch 204: val_accuracy did not improve from 0.68571
#
# Epoch 205: val_accuracy did not improve from 0.68571
#
# Epoch 206: val_accuracy did not improve from 0.68571
#
# Epoch 207: val_accuracy did not improve from 0.68571
#
# Epoch 208: val_accuracy did not improve from 0.68571
#
# Epoch 209: val_accuracy did not improve from 0.68571
#
# Epoch 210: val_accuracy did not improve from 0.68571
#
# Epoch 211: val_accuracy did not improve from 0.68571
#
# Epoch 212: val_accuracy did not improve from 0.68571
#
# Epoch 213: val_accuracy did not improve from 0.68571
#
# Epoch 214: val_accuracy did not improve from 0.68571
#
# Epoch 215: val_accuracy did not improve from 0.68571
#
# Epoch 216: val_accuracy did not improve from 0.68571
#
# Epoch 217: val_accuracy did not improve from 0.68571
#
# Epoch 218: val_accuracy did not improve from 0.68571
#
# Epoch 219: val_accuracy did not improve from 0.68571
#
# ...
#
# Epoch 12: val_accuracy did not improve from 0.28571
#
# Epoch 13: val_accuracy did not improve from 0.28571
#
# Epoch 14: val_accuracy did not improve from 0.28571
#
# Epoch 15: val_accuracy did not improve from 0.28571
#
# Epoch 16: val_accuracy improved from 0.28571 to 0.42857, saving model to /home/metzgeka/ml_project/datasets/symbols/dataset1/chpt/5-chpt.model.keras
#
# Epoch 17: val_accuracy did not improve from 0.42857
#
# Epoch 18: val_accuracy did not improve from 0.42857
#
# Epoch 19: val_accuracy did not improve from 0.42857
#
# Epoch 20: val_accuracy did not improve from 0.42857
#
# Epoch 21: val_accuracy did not improve from 0.42857
#
# Epoch 22: val_accuracy did not improve from 0.42857
#
# Epoch 23: val_accuracy did not improve from 0.42857
#
# Epoch 24: val_accuracy did not improve from 0.42857
#
# Epoch 25: val_accuracy did not improve from 0.42857
#
# Epoch 26: val_accuracy did not improve from 0.42857
#
# Epoch 27: val_accuracy did not improve from 0.42857
#
# Epoch 28: val_accuracy did not improve from 0.42857
#
# Epoch 29: val_accuracy did not improve from 0.42857
#
# Epoch 30: val_accuracy did not improve from 0.42857
#
# Epoch 31: val_accuracy did not improve from 0.42857
#
# Epoch 32: val_accuracy did not improve from 0.42857
#
# Epoch 33: val_accuracy did not improve from 0.42857
#
# Epoch 34: val_accuracy did not improve from 0.42857
#
# Epoch 35: val_accuracy did not improve from 0.42857
#
# Epoch 36: val_accuracy did not improve from 0.42857
#
# Epoch 37: val_accuracy did not improve from 0.42857
#
# Epoch 38: val_accuracy did not improve from 0.42857
#
# Epoch 39: val_accuracy did not improve from 0.42857
#
# Epoch 40: val_accuracy did not improve from 0.42857
#
# Epoch 41: val_accuracy did not improve from 0.42857
#
# Epoch 42: val_accuracy did not improve from 0.42857
#
# Epoch 43: val_accuracy did not improve from 0.42857
#
# Epoch 44: val_accuracy did not improve from 0.42857
#
# Epoch 45: val_accuracy did not improve from 0.42857
#
# Epoch 46: val_accuracy did not improve from 0.42857
#
# Epoch 47: val_accuracy did not improve from 0.42857
#
# Epoch 48: val_accuracy did not improve from 0.42857
#
# Epoch 49: val_accuracy did not improve from 0.42857
#
# Epoch 50: val_accuracy did not improve from 0.42857
#
# Epoch 51: val_accuracy did not improve from 0.42857
#
# Epoch 52: val_accuracy did not improve from 0.42857
#
# Epoch 53: val_accuracy did not improve from 0.42857
#
# Epoch 54: val_accuracy did not improve from 0.42857
#
# Epoch 55: val_accuracy did not improve from 0.42857
#
# Epoch 56: val_accuracy did not improve from 0.42857
#
# Epoch 57: val_accuracy did not improve from 0.42857
#
# Epoch 58: val_accuracy did not improve from 0.42857
#
# Epoch 59: val_accuracy did not improve from 0.42857
#
# Epoch 60: val_accuracy did not improve from 0.42857
#
# Epoch 61: val_accuracy did not improve from 0.42857
#
# Epoch 62: val_accuracy did not improve from 0.42857
#
# Epoch 63: val_accuracy did not improve from 0.42857
#
# Epoch 64: val_accuracy did not improve from 0.42857
#
# Epoch 65: val_accuracy did not improve from 0.42857
#
# Epoch 66: val_accuracy did not improve from 0.42857
#
# Epoch 67: val_accuracy did not improve from 0.42857
#
# Epoch 68: val_accuracy did not improve from 0.42857
#
# Epoch 69: val_accuracy did not improve from 0.42857
#
# Epoch 70: val_accuracy did not improve from 0.42857
#
# Epoch 71: val_accuracy did not improve from 0.42857
#
# Epoch 72: val_accuracy did not improve from 0.42857
#
# Epoch 73: val_accuracy did not improve from 0.42857
#
# Epoch 74: val_accuracy did not improve from 0.42857
#
# Epoch 75: val_accuracy did not improve from 0.42857
#
# Epoch 76: val_accuracy did not improve from 0.42857
#
# Epoch 77: val_accuracy did not improve from 0.42857
#
# Epoch 78: val_accuracy did not improve from 0.42857
#
# Epoch 79: val_accuracy did not improve from 0.42857
#
# Epoch 80: val_accuracy did not improve from 0.42857
#
# Epoch 81: val_accuracy did not improve from 0.42857
#
# Epoch 82: val_accuracy improved from 0.42857 to 0.48571, saving model to /home/metzgeka/ml_project/datasets/symbols/dataset1/chpt/5-chpt.model.keras
#
# Epoch 83: val_accuracy did not improve from 0.48571
#
# Epoch 84: val_accuracy did not improve from 0.48571
#
# Epoch 85: val_accuracy improved from 0.48571 to 0.57143, saving model to /home/metzgeka/ml_project/datasets/symbols/dataset1/chpt/5-chpt.model.keras
#
# Epoch 86: val_accuracy did not improve from 0.57143
#
# Epoch 87: val_accuracy did not improve from 0.57143
#
# Epoch 88: val_accuracy did not improve from 0.57143
#
# Epoch 89: val_accuracy did not improve from 0.57143
#
# Epoch 90: val_accuracy did not improve from 0.57143
#
# Epoch 91: val_accuracy did not improve from 0.57143
#
# Epoch 92: val_accuracy did not improve from 0.57143
#
# Epoch 93: val_accuracy did not improve from 0.57143
#
# Epoch 94: val_accuracy did not improve from 0.57143
#
# Epoch 95: val_accuracy did not improve from 0.57143
#
# Epoch 96: val_accuracy did not improve from 0.57143
#
# Epoch 97: val_accuracy did not improve from 0.57143
#
# Epoch 98: val_accuracy did not improve from 0.57143
#
# Epoch 99: val_accuracy did not improve from 0.57143
#
# Epoch 100: val_accuracy did not improve from 0.57143
#
# Epoch 101: val_accuracy did not improve from 0.57143
#
# Epoch 102: val_accuracy did not improve from 0.57143
#
# Epoch 103: val_accuracy did not improve from 0.57143
#
# Epoch 104: val_accuracy did not improve from 0.57143
#
# Epoch 105: val_accuracy did not improve from 0.57143
#
# Epoch 106: val_accuracy did not improve from 0.57143
#
# Epoch 107: val_accuracy did not improve from 0.57143
#
# Epoch 108: val_accuracy did not improve from 0.57143
#
# Epoch 109: val_accuracy did not improve from 0.57143
#
# Epoch 110: val_accuracy did not improve from 0.57143
#
# Epoch 111: val_accuracy did not improve from 0.57143
#
# Epoch 112: val_accuracy did not improve from 0.57143
#
# Epoch 113: val_accuracy did not improve from 0.57143
#
# Epoch 114: val_accuracy did not improve from 0.57143
#
# Epoch 115: val_accuracy did not improve from 0.57143
#
# Epoch 116: val_accuracy did not improve from 0.57143
#
# Epoch 117: val_accuracy did not improve from 0.57143
#
# Epoch 118: val_accuracy did not improve from 0.57143
#
# Epoch 119: val_accuracy did not improve from 0.57143
#
# Epoch 120: val_accuracy did not improve from 0.57143
#
# Epoch 121: val_accuracy did not improve from 0.57143
#
# Epoch 122: val_accuracy did not improve from 0.57143
#
# Epoch 123: val_accuracy did not improve from 0.57143
#
# Epoch 124: val_accuracy did not improve from 0.57143
#
# Epoch 125: val_accuracy did not improve from 0.57143
#
# Epoch 126: val_accuracy did not improve from 0.57143
#
# Epoch 127: val_accuracy did not improve from 0.57143
#
# Epoch 128: val_accuracy did not improve from 0.57143
#
# Epoch 129: val_accuracy did not improve from 0.57143
#
# Epoch 130: val_accuracy did not improve from 0.57143
#
# Epoch 131: val_accuracy did not improve from 0.57143
#
# Epoch 132: val_accuracy did not improve from 0.57143
#
# Epoch 133: val_accuracy did not improve from 0.57143
#
# Epoch 134: val_accuracy did not improve from 0.57143
#
# Epoch 135: val_accuracy did not improve from 0.57143
#
# Epoch 136: val_accuracy did not improve from 0.57143
#
# Epoch 137: val_accuracy did not improve from 0.57143
#
# Epoch 138: val_accuracy did not improve from 0.57143
#
# Epoch 139: val_accuracy did not improve from 0.57143
#
# Epoch 140: val_accuracy did not improve from 0.57143
#
# Epoch 141: val_accuracy did not improve from 0.57143
#
# Epoch 142: val_accuracy did not improve from 0.57143
#
# Epoch 143: val_accuracy did not improve from 0.57143
#
# Epoch 144: val_accuracy did not improve from 0.57143
#
# Epoch 145: val_accuracy did not improve from 0.57143
#
# Epoch 146: val_accuracy did not improve from 0.57143
#
# Epoch 147: val_accuracy did not improve from 0.57143
#
# Epoch 148: val_accuracy did not improve from 0.57143
#
# Epoch 149: val_accuracy did not improve from 0.57143
#
# Epoch 150: val_accuracy did not improve from 0.57143
#
# Epoch 151: val_accuracy did not improve from 0.57143
#
# Epoch 152: val_accuracy did not improve from 0.57143
#
# Epoch 153: val_accuracy did not improve from 0.57143
#
# Epoch 154: val_accuracy did not improve from 0.57143
#
# Epoch 155: val_accuracy did not improve from 0.57143
#
# Epoch 156: val_accuracy did not improve from 0.57143
#
# Epoch 157: val_accuracy did not improve from 0.57143
#
# Epoch 158: val_accuracy did not improve from 0.57143
#
# Epoch 159: val_accuracy did not improve from 0.57143
#
# Epoch 160: val_accuracy did not improve from 0.57143
#
# Epoch 161: val_accuracy did not improve from 0.57143
#
# Epoch 162: val_accuracy did not improve from 0.57143
#
# Epoch 163: val_accuracy did not improve from 0.57143
#
# Epoch 164: val_accuracy did not improve from 0.57143
#
# Epoch 165: val_accuracy did not improve from 0.57143
#
# Epoch 166: val_accuracy did not improve from 0.57143
#
# Epoch 167: val_accuracy did not improve from 0.57143
#
# Epoch 168: val_accuracy did not improve from 0.57143
#
# Epoch 169: val_accuracy did not improve from 0.57143
#
# Epoch 170: val_accuracy did not improve from 0.57143
#
# Epoch 171: val_accuracy did not improve from 0.57143
#
# Epoch 172: val_accuracy did not improve from 0.57143
#
# Epoch 173: val_accuracy did not improve from 0.57143
#
# Epoch 174: val_accuracy did not improve from 0.57143
#
# Epoch 175: val_accuracy did not improve from 0.57143
#
# Epoch 176: val_accuracy did not improve from 0.57143
#
# Epoch 177: val_accuracy did not improve from 0.57143
#
# Epoch 178: val_accuracy did not improve from 0.57143
#
# Epoch 179: val_accuracy did not improve from 0.57143
#
# Epoch 180: val_accuracy did not improve from 0.57143
#
# Epoch 181: val_accuracy did not improve from 0.57143
#
# Epoch 182: val_accuracy did not improve from 0.57143
#
# Epoch 183: val_accuracy did not improve from 0.57143
#
# Epoch 184: val_accuracy did not improve from 0.57143
#
# Epoch 185: val_accuracy did not improve from 0.57143
#
# Epoch 186: val_accuracy did not improve from 0.57143
#
# Epoch 187: val_accuracy did not improve from 0.57143
#
# Epoch 188: val_accuracy did not improve from 0.57143
#
# Epoch 189: val_accuracy did not improve from 0.57143
#
# Epoch 190: val_accuracy did not improve from 0.57143
#
# Epoch 191: val_accuracy did not improve from 0.57143
#
# Epoch 192: val_accuracy did not improve from 0.57143
#
# Epoch 193: val_accuracy did not improve from 0.57143
#
# Epoch 194: val_accuracy did not improve from 0.57143
#
# Epoch 195: val_accuracy did not improve from 0.57143
#
# Epoch 196: val_accuracy did not improve from 0.57143
#
# Epoch 197: val_accuracy improved from 0.57143 to 0.60000, saving model to /home/metzgeka/ml_project/datasets/symbols/dataset1/chpt/5-chpt.model.keras
#
# Epoch 198: val_accuracy did not improve from 0.60000
#
# Epoch 199: val_accuracy did not improve from 0.60000
#
# Epoch 200: val_accuracy did not improve from 0.60000
#
# Epoch 201: val_accuracy did not improve from 0.60000
#
# Epoch 202: val_accuracy did not improve from 0.60000
#
# Epoch 203: val_accuracy did not improve from 0.60000
#
# Epoch 204: val_accuracy did not improve from 0.60000
#
# Epoch 205: val_accuracy did not improve from 0.60000
#
# Epoch 206: val_accuracy did not improve from 0.60000
#
# Epoch 207: val_accuracy did not improve from 0.60000
#
# Epoch 208: val_accuracy did not improve from 0.60000
#
# Epoch 209: val_accuracy did not improve from 0.60000
#
# Epoch 210: val_accuracy did not improve from 0.60000
#
# Epoch 211: val_accuracy did not improve from 0.60000
#
# Epoch 212: val_accuracy did not improve from 0.60000
#
# Epoch 213: val_accuracy did not improve from 0.60000
#
# Epoch 214: val_accuracy did not improve from 0.60000
#
# Epoch 215: val_accuracy did not improve from 0.60000
#
# Epoch 216: val_accuracy did not improve from 0.60000
#
# Epoch 217: val_accuracy did not improve from 0.60000
#
# Epoch 218: val_accuracy did not improve from 0.60000
#
# Epoch 219: val_accuracy did not improve from 0.60000
#
# Epoch 220: val_accuracy did not improve from 0.60000
#
# Epoch 221: val_accuracy did not improve from 0.60000
#
# Epoch 222: val_accuracy did not improve from 0.60000
#
# Epoch 223: val_accuracy did not improve from 0.60000
#
# Epoch 224: val_accuracy did not improve from 0.60000
#
# Epoch 225: val_accuracy did not improve from 0.60000
#
# Epoch 226: val_accuracy did not improve from 0.60000
#
# Epoch 227: val_accuracy did not improve from 0.60000
#
# Epoch 228: val_accuracy did not improve from 0.60000
#
# Epoch 229: val_accuracy did not improve from 0.60000
#
# Epoch 230: val_accuracy did not improve from 0.60000
#
# Epoch 231: val_accuracy did not improve from 0.60000
#
# Epoch 232: val_accuracy did not improve from 0.60000
#
# Epoch 233: val_accuracy did not improve from 0.60000
#
# Epoch 234: val_accuracy did not improve from 0.60000
#
# Epoch 235: val_accuracy did not improve from 0.60000
#
# Epoch 236: val_accuracy did not improve from 0.60000
#
# Epoch 237: val_accuracy did not improve from 0.60000
#
# Epoch 238: val_accuracy did not improve from 0.60000
#
# Epoch 239: val_accuracy did not improve from 0.60000
#
# Epoch 240: val_accuracy did not improve from 0.60000
#
# Epoch 241: val_accuracy did not improve from 0.60000
#
# Epoch 242: val_accuracy did not improve from 0.60000
#
# Epoch 243: val_accuracy did not improve from 0.60000
#
# Epoch 244: val_accuracy did not improve from 0.60000
#
# Epoch 245: val_accuracy did not improve from 0.60000
#
# Epoch 246: val_accuracy did not improve from 0.60000
#
# Epoch 247: val_accuracy did not improve from 0.60000
#
# Epoch 248: val_accuracy did not improve from 0.60000
#
# Epoch 249: val_accuracy did not improve from 0.60000
#
# Epoch 250: val_accuracy did not improve from 0.60000
#
# Epoch 251: val_accuracy did not improve from 0.60000
#
# Epoch 252: val_accuracy did not improve from 0.60000
#
# Epoch 253: val_accuracy did not improve from 0.60000
#
# Epoch 254: val_accuracy did not improve from 0.60000
#
# Epoch 255: val_accuracy did not improve from 0.60000
#
# Epoch 256: val_accuracy did not improve from 0.60000
#
# Epoch 257: val_accuracy did not improve from 0.60000
#
# Epoch 258: val_accuracy did not improve from 0.60000
#
# Epoch 259: val_accuracy did not improve from 0.60000
#
# Epoch 260: val_accuracy did not improve from 0.60000
#
# Epoch 261: val_accuracy did not improve from 0.60000
#
# Epoch 262: val_accuracy did not improve from 0.60000
#
# Epoch 263: val_accuracy did not improve from 0.60000
#
# Epoch 264: val_accuracy did not improve from 0.60000
#
# Epoch 265: val_accuracy did not improve from 0.60000
#
# Epoch 266: val_accuracy did not improve from 0.60000
#
# Epoch 267: val_accuracy did not improve from 0.60000
#
# Epoch 268: val_accuracy did not improve from 0.60000
#
# Epoch 269: val_accuracy did not improve from 0.60000
#
# Epoch 270: val_accuracy did not improve from 0.60000
#
# Epoch 271: val_accuracy did not improve from 0.60000
#
# Epoch 272: val_accuracy did not improve from 0.60000
#
# Epoch 273: val_accuracy did not improve from 0.60000
#
# Epoch 274: val_accuracy did not improve from 0.60000
#
# Epoch 275: val_accuracy did not improve from 0.60000
#
# Epoch 276: val_accuracy did not improve from 0.60000
#
# Epoch 277: val_accuracy did not improve from 0.60000
#
# Epoch 278: val_accuracy did not improve from 0.60000
#
# Epoch 279: val_accuracy did not improve from 0.60000
#
# Epoch 280: val_accuracy did not improve from 0.60000
#
# Epoch 281: val_accuracy did not improve from 0.60000
#
# Epoch 282: val_accuracy did not improve from 0.60000
#
# Epoch 283: val_accuracy did not improve from 0.60000
#
# Epoch 284: val_accuracy did not improve from 0.60000
#
# Epoch 285: val_accuracy did not improve from 0.60000
#
# Epoch 286: val_accuracy did not improve from 0.60000
#
# Epoch 287: val_accuracy did not improve from 0.60000
#
# Epoch 288: val_accuracy did not improve from 0.60000
#
# Epoch 289: val_accuracy did not improve from 0.60000
#
# Epoch 290: val_accuracy did not improve from 0.60000
#
# Epoch 291: val_accuracy did not improve from 0.60000
#
# Epoch 292: val_accuracy did not improve from 0.60000
#
# Epoch 293: val_accuracy did not improve from 0.60000
#
# Epoch 294: val_accuracy did not improve from 0.60000
#
# Epoch 295: val_accuracy did not improve from 0.60000
#
# Epoch 296: val_accuracy did not improve from 0.60000
#
# Epoch 297: val_accuracy did not improve from 0.60000
#
# Epoch 298: val_accuracy did not improve from 0.60000
#
# Epoch 299: val_accuracy did not improve from 0.60000
#
# Epoch 300: val_accuracy did not improve from 0.60000
# #################################################
